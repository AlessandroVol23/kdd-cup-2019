# %%
import pandas as pd

# %%
df_train = pd.read_pickle("../data/processed/df_train.pickle")

# %%
df_train.shape
# Out:
# (2101060, 15)

# %%
# !ls ../data/processed
# Out:
# df_test.pickle	df_train.pickle

# %%
df_train.sid.nunique()
# Out:
# 453336

# %%
df_raw = pd.read_csv("../data/raw/data_set_phase1/train_queries.csv")

# %%
df_raw.head()
# Out:
#        sid       pid             req_time             o             d
# 0  3000821       NaN  2018-11-02 17:54:30  116.29,39.97  116.32,39.96
# 1  3085857  210736.0  2018-11-16 10:53:10  116.39,39.84  116.33,39.79
# 2  2944522       NaN  2018-10-06 10:33:58  116.31,39.93  116.27,40.00
# 3   559931  202427.0  2018-11-23 14:54:11  116.27,39.88  116.39,39.90
# 4  2819352  172251.0  2018-10-30 11:48:41  116.34,39.96  116.37,39.86

# %%
df_raw.sid.nunique()
# Out:
# 500000

# %%
df_plans = pd.read_csv("../data/raw/data_set_phase1/train_plans.csv")

# %%
df_plans.head()
# Out:
#        sid            plan_time  \
# 0  1709112  2018-11-04 11:45:04
# 1  3327773  2018-10-16 19:09:29
# 2  3285959  2018-11-25 15:05:22
# 3  1616170  2018-10-03 14:42:40
# 4   351369  2018-10-05 19:52:37
#
#                                                plans
# 0  [{"distance": 32303, "price": 600, "eta": 5087...
# 1  [{"distance": 3427, "price": 300, "eta": 627, ...
# 2  [{"distance": 36234, "price": 1100, "eta": 931...
# 3  [{"distance": 11450, "price": 400, "eta": 2801...
# 4  [{"distance": 18495, "price": 600, "eta": 4271...

# %%
df_plans
# Out:
#             sid            plan_time  \
# 0       1709112  2018-11-04 11:45:04
# 1       3327773  2018-10-16 19:09:29
# 2       3285959  2018-11-25 15:05:22
# 3       1616170  2018-10-03 14:42:40
# 4        351369  2018-10-05 19:52:37
# 5        749203  2018-10-01 07:03:52
# 6       3005789  2018-10-22 11:45:20
# 7       1897386  2018-11-13 18:51:27
# 8        845203  2018-11-26 12:43:56
# 9        536341  2018-11-23 19:34:38
# 10      2015965  2018-10-14 08:05:50
# 11      2398670  2018-11-14 15:43:32
# 12      1944449  2018-10-11 16:29:29
# 13      2985086  2018-11-02 16:23:33
# 14       593793  2018-11-11 11:13:56
# 15       862480  2018-11-26 10:38:04
# 16       476608  2018-11-09 11:32:28
# 17       953020  2018-10-24 22:12:34
# 18      2467443  2018-11-30 22:42:04
# 19      3331590  2018-10-16 09:58:44
# 20      1683338  2018-10-23 10:59:04
# 21       750368  2018-10-01 12:27:32
# 22      3383023  2018-11-24 10:36:28
# 23      1622080  2018-10-03 10:54:48
# ...

# %%
df_train.head()
# Out:
#        sid           click_time  click_mode  distance_plan   eta    price  \
# 0  2848914  2018-11-17 18:42:17           1          53156  6456    700.0
# 1  2848914  2018-11-17 18:42:17           1          48112  3535    700.0
# 2  2848914  2018-11-17 18:42:17           1          48112  3655  16500.0
# 3  2848914  2018-11-17 18:42:17           1          51641  8871   1200.0
# 4  2629085  2018-10-12 16:28:13           3          13207  2790    400.0
#
#    transport_mode            plan_time       pid             req_time  o_long  \
# 0               1  2018-11-17 12:56:15  101804.0  2018-11-17 12:56:15  116.36
# 1               3  2018-11-17 12:56:15  101804.0  2018-11-17 12:56:15  116.36
# 2               4  2018-11-17 12:56:15  101804.0  2018-11-17 12:56:15  116.36
# 3               1  2018-11-17 12:56:15  101804.0  2018-11-17 12:56:15  116.36
# 4               9  2018-10-12 16:27:55  203797.0  2018-10-12 16:27:55  116.35
#
#    o_lat  d_long  d_lat  distance_query
# ...
